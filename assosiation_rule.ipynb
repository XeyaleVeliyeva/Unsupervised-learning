# %% [markdown]
# <a href="https://colab.research.google.com/github/XeyaleVeliyeva/Unsupervised-learning/blob/main/assosiation_rule.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mlxtend

# %%
import pandas as pd

dataset = [['Çörək', 'Yağ', 'Süd'],
           ['Çörək', 'Yağ', 'Süd'],
           ['Çörək', 'Yağ', 'Süd'],
           ['Çörək', 'Yağ', 'Süd'],
           ['Çörək', 'Yağ', 'Süd'],
           ['Çörək', 'Yağ', 'Süd'],
           ['Çörək', 'Yağ'],
           ['Çörək', 'Yağ'],
           ['Çörək', 'Süd'],
           ['Çörək', 'Yağ'],
           ['Çörək', 'Süd'],
           ['Süd', 'Yağ'],
           ['Süd', 'Yağ'],
           ]

# %%
from mlxtend.preprocessing import TransactionEncoder

data = TransactionEncoder()
data_onehot = data.fit(dataset).transform(dataset)

df = pd.DataFrame(data_onehot, columns=data.columns_)
df
# Out:
#       Süd    Yağ  Çörək
# 0    True   True   True
# 1    True   True   True
# 2    True   True   True
# 3    True   True   True
# 4    True   True   True
# 5    True   True   True
# 6   False   True   True
# 7   False   True   True
# 8    True  False   True
# 9   False   True   True
# 10   True  False   True
# 11   True   True  False
# 12   True   True  False

# %%
data_onehot
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True],
#        [False,  True,  True],
#        [False,  True,  True],
#        [ True, False,  True],
#        [False,  True,  True],
#        [ True, False,  True],
#        [ True,  True, False],
#        [ True,  True, False]])

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)
frequent_itemsets
# Out:
#     support      itemsets
# 0  0.769231         (Süd)
# 1  0.846154         (Yağ)
# 2  0.846154       (Çörək)
# 3  0.615385    (Yağ, Süd)
# 4  0.615385  (Çörək, Süd)
# 5  0.692308  (Yağ, Çörək)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#   antecedents consequents   support  confidence      lift
# 0       (Yağ)       (Süd)  0.615385    0.727273  0.945455
# 1       (Süd)       (Yağ)  0.615385    0.800000  0.945455
# 2     (Çörək)       (Süd)  0.615385    0.727273  0.945455
# 3       (Süd)     (Çörək)  0.615385    0.800000  0.945455
# 4       (Yağ)     (Çörək)  0.692308    0.818182  0.966942
# 5     (Çörək)       (Yağ)  0.692308    0.818182  0.966942
