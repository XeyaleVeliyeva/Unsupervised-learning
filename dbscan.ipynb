# %% [markdown]
# <a href="https://colab.research.google.com/github/XeyaleVeliyeva/Unsupervised-learning/blob/main/dbscan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons

# %%
X, _ = make_moons(n_samples=300,noise = 0.05, random_state=42)

# %%
dbscan = DBSCAN(eps=0.2, min_samples=5)
labels = dbscan.fit_predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=10)
plt.title("DBSCAN")
plt.show()
